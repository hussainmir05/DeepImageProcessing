# %% [markdown]
# <h1> <center> Khadim Hussain <center><h1>
# <h1> <center> 19-CP-71 <center><h1>
# <h1> <center> DIP LAB 05<center><h1>

# %% [markdown]
# # task 01

# %%
# import Opencv
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
# Open the image.
# img = cv2.imread('drive/MyDrive/DIP LAB/img2.jfif', cv2.IMREAD_GRAYSCALE)

img = cv2.imread("/content/cover fb page-01 (1).jpg", cv2.IMREAD_GRAYSCALE)

print('Resized Dimensions : ',img.shape)
cv2_imshow(img)
cv2.waitKey(0)
cv2.destroyAllWindows()
for i in range(img.shape[0]):
 for j in range(img.shape[1]):
  if img[i,j]<180:
   img[i,j]=img[i,j]
  if img[i,j]>180:
   img[i,j]= 255 - img[i,j]
print()   
cv2_imshow(img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Resized Dimensions :  (348, 800)
# <PIL.Image.Image image mode=L size=800x348 at 0x7F2B58607650>
# <PIL.Image.Image image mode=L size=800x348 at 0x7F2B585F6490>

# %% [markdown]
# # Task 02

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
# Open the image.

# Trying 4 gamma values.
for gamma in [0.1, 0.5, 1.2, 2.2]:
  # Apply gamma correction.
  gamma_corrected = np.array(255*(img / 255) ** gamma, dtype = 'uint8')
# Save edited images.
  cv2.imwrite('/gamma_transformed'+str(gamma)+'.jpg', gamma_corrected)
  img = cv2.imread('gamma_transformed'+str(gamma)+ '.jpg')
  print('gamma')
  print(gamma)
  # cv2_imshow(img)
# Out:
# gamma
# 0.1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-4a9f05ea3c25> in <module>
#       8 for gamma in [0.1, 0.5, 1.2, 2.2]:
#       9   # Apply gamma correction.
# ---> 10   gamma_corrected = np.array(255*(img / 255) ** gamma, dtype = 'uint8')
#      11 # Save edited images.
#      12   cv2.imwrite('/gamma_transformed'+str(gamma)+'.jpg', gamma_corrected)
#
# TypeError: unsupported operand type(s) for /: 'NoneType' and 'int'

# %% [markdown]
# # task 03

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
# Function to map each intensity level to output intensity level.
def pixelVal(pix, r1, s1, r2, s2):
 if (0 <= pix and pix <= r1):
  return (s1 / r1)*pix
 elif (r1 < pix and pix <= r2):
  return ((s2 - s1)/(r2 - r1)) * (pix - r1) + s1
 else:
  return ((255 - s2)/(255 - r2)) * (pix - r2) + s2
# Open the image.
img = cv2.imread('drive/MyDrive/DIP LAB/img.jfif', cv2.IMREAD_GRAYSCALE)
# Define parameters.
r1 = 70
s1 = 0
r2 = 140
s2 = 255
# Vectorize the function to apply it to each value in the Numpy array.
pixelVal_vec = np.vectorize(pixelVal)
# Apply contrast stretching.
contrast_stretched = pixelVal_vec(img, r1, s1, r2, s2)
# Save edited image.
cv2.imwrite('contrast_stretch.jpg', contrast_stretched)
img = cv2.imread('contrast_stretch.jpg')
cv2_imshow(img)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-effa1ed7c74e> in <module>
#      20 pixelVal_vec = np.vectorize(pixelVal)
#      21 # Apply contrast stretching.
# ---> 22 contrast_stretched = pixelVal_vec(img, r1, s1, r2, s2)
#      23 # Save edited image.
#      24 cv2.imwrite('contrast_stretch.jpg', contrast_stretched)
#
# /usr/local/lib/python3.7/dist-packages/numpy/lib/function_base.py in __call__(self, *args, **kwargs)
#    2161             vargs.extend([kwargs[_n] for _n in names])
#    2162
# -> 2163         return self._vectorize_call(func=func, args=vargs)
#    2164
#    2165     def _get_ufunc_and_otypes(self, func, args):
#
# /usr/local/lib/python3.7/dist-packages/numpy/lib/function_base.py in _vectorize_call(self, func, args)
#    2239             res = func()
#    2240         else:
# ...
