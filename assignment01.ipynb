# %% [markdown]
# <h1> <center> Khadim Hussain <center><h1>
# <h1> <center> 19-CP-71 <center><h1>
# <h1> <center> Assignment 01<center><h1>

# %% [markdown]
# ## task 01

# %% [markdown]
# Write 3 different Python functions that can create the images
# given below. Code them in such so that the size of the image
# itself, size of boxes, size of lines and number of horizontal
# and vertical lines are entered by the user.

# %% [markdown]
# - part 01

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

h=int(input('height'))
w=int(input('width'))
image=np.zeros((h,w,3))

# Create a named colour
image[int(h/4):int(h/2)+int(h/4),int(w/4):int(w/2)+int(w/4)]=(255,255,255)

red = [0,0,255]

# Change one pixel
from google.colab.patches import cv2_imshow
image[10,5]=red
cv2_imshow(image)
# Out:
# height200
# width800
# <PIL.Image.Image image mode=RGB size=800x200 at 0x7F9B967C7790>

# %% [markdown]
# - Part 02

# %%
from numpy.matrixlib.defmatrix import N
from re import T
import numpy as np
from google.colab.patches import cv2_imshow

import cv2
# Creating a black screen image using nupy.zeros function
# w=int(input('width'))
# h=int(input('height'))

Img = np.zeros((h, w, 3), dtype='uint8')
# White color in BGR
color = (255, 250, 255)
# Line thickness of 9 px
n=int(input('nbr of vertical lines'))
n1=int(input('nbr of horizontal lines'))
f=w/n
f1=h/n1

thickness = 9
x=w/int(f)
x1=w/int(f1)
t=int(x)
t1=int(x1)
k=int(f)
k1=int(f1)
for i in range(7):
  # Start coordinate, here (100, 100). It represents the top left corner of image
  start_point = (t, 0)
  start = (0, t1)
  # End coordinate, here (450, 450). It represents the bottom right corner of the image according to resolution
  end_point = (t, h)
  end = (w, t1)
  t+=k
  t1+=k1
  # print(t)
  image = cv2.line(Img, start_point, end_point, color, thickness)
  image = cv2.line(Img, start, end, color, thickness)


print(Img.shape)
# Using cv2.line() method to draw a diagonal green line with thickness of 9 px
# Display the image
# cv2_imshow( image)
plt.imshow(image)

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# nbr of vertical lines5
# nbr of horizontal lines6
# (400, 800, 3)

# %% [markdown]
# - part 03

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

image=np.ones((h,w,3))

# Create a named colour
# image[int(h/4):int(h/2)+int(h/4),int(w/4):int(w/2)+int(w/4)]=(255,255,255)
image[:,:]=(255,255,255)
image[0:k1,0:k]=(0,0,0)
image[0:k1,(w-k):w]=(0,0,0)
image[h-k1:h,0:k]=(0,0,0)
image[h-k1:h,w-k:w]=(0,0,0)

# red = [0,0,255]

# Change one pixel
from google.colab.patches import cv2_imshow
image[10,5]=red
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=800x400 at 0x7F9B96787790>

# %% [markdown]
# # Task 02
# Write a function to create a white image size entered by the
# user and then create 4 boxes of Black, Blue, Green and Red
# respectively on each corner of the image as shown below. The
# size of the colored boxes should be 1/10th the size of the
# image.

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

image=np.ones((h,w,3))

# Create a named colour
# image[int(h/4):int(h/2)+int(h/4),int(w/4):int(w/2)+int(w/4)]=(255,255,255)
image[:,:]=(255,255,255)
image[0:int(h/10),0:int(w/10)]=(0,0,0)
image[0:int(h/10),(w-int(h/10)):w]=(255,0,0)
image[h-int(h/10):h,0:int(w/10)]=(0,255,0)
image[h-int(h/10):h,w-int(w/10):w]=(0,0,255)

# red = [0,0,255]

# Change one pixel
from google.colab.patches import cv2_imshow
image[10,5]=red
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=800x200 at 0x7F9B967C9D90>

# %% [markdown]
# # task 03

# %% [markdown]
# Read any image that you want and save it in gray scale. Now mirror
# the image that you have read at center i.e., the upper half of the
# image should be the copy of the lower half but mirrored.
# Write the image to the disk. See the image below.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab import files

img = cv2.imread("/content/A1P3.PNG",cv2.IMREAD_COLOR)
img=img[:(img.shape[1]//2),:]
img1 = cv2.flip(img, 0)
kha=img1+img
print('\n')
cv2_imshow(img)
print('original image\n')

cv2_imshow(kha)
print('desired image\\ mirrored Image')

# print(type(img.shape[0]))
# Out:
# <PIL.Image.Image image mode=RGB size=259x129 at 0x7F9B96787F50>
# original image
# <PIL.Image.Image image mode=RGB size=259x129 at 0x7F9B96881B10>
# desired image\ mirrored Image

# %% [markdown]
# astori is here
